# %%
import pandas as pd
import matplotlib.pyplot as plt
store=pd.read_csv("/Users/paulcolton/Desktop/Ladan/retail-data-analytics/stores data-set.CSV")
sales=pd.read_csv("/Users/paulcolton/Desktop/Ladan/retail-data-analytics/sales data-set.CSV")
features=pd.read_csv("/Users/paulcolton/Desktop/Ladan/retail-data-analytics/Features data set.csv")

# %%
df=pd.merge(sales,features, on=['Store','Date', 'IsHoliday'], how='left')
df=pd.merge(df,store,on=['Store'],how='right')

# %%
import seaborn as sns
sns.boxplot(x='Type',y='Weekly_Sales',data=df3)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression(normalize=True)
model.fit(df3[['Size']],df3['Weekly_Sales'])
import numpy as np
plt.figure(figsize=(20,10))
plt.plot(df3.Size, df3.Weekly_Sales,'ok',markersize=10)
plt.xlabel('Store Size')
plt.ylabel('Total Sales')
xfit=(10000,300000)
yfit=model.predict(10000)
yfit2=model.predict(300000)
plt.plot([10000,300000],[yfit,yfit2])
plt.show()
print (model.get_params)
# Out:
# <bound method BaseEstimator.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)>

# %%
x=df[df.Store==1]
plt.figure(figsize=(20,10))
plt.plot(x.Temperature, x.Weekly_Sales,'p',markersize=5)
plt.xlabel('Temperature')
plt.ylabel('Weekly Sales')
plt.show()

# %%
import seaborn as sns
sns.boxplot(x='IsHoliday',y='Weekly_Sales',data=df,whis=0.5)
plt.ylim((0,60000))
# Out:
# (0, 60000)

# %%
store.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
sales.head(3)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False

# %%
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1  05/02/2010      24924.50      False        42.31       2.572
# 1      1     1  12/02/2010      46039.49       True        38.51       2.548
# 2      1     1  19/02/2010      41595.55      False        39.93       2.514
# 3      1     1  26/02/2010      19403.54      False        46.63       2.561
# 4      1     1  05/03/2010      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment Type    Size
# 0         8.106    A  151315
# ...

# %%
df= df.drop_duplicates()

# %%
df.describe()
# Out:
#                Store           Dept   Weekly_Sales    Temperature  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123      60.090059
# std        12.785297      30.492054   22711.183519      18.447931
# min         1.000000       1.000000   -4988.940000      -2.060000
# 25%        11.000000      18.000000    2079.650000      46.680000
# 50%        22.000000      37.000000    7612.030000      62.090000
# 75%        33.000000      74.000000   20205.852500      74.280000
# max        45.000000      99.000000  693099.360000     100.140000
#
#           Fuel_Price      MarkDown1      MarkDown2      MarkDown3  \
# count  421570.000000  150681.000000  111248.000000  137091.000000
# mean        3.361027    7246.420196    3334.628621    1439.421384
# std         0.458515    8291.221345    9475.357325    9623.078290
# min         2.472000       0.270000    -265.760000     -29.100000
# ...

# %%
df_average_sales_week.sort_values('Weekly_Sales', ascending=False)
# Out:
#            Date  Weekly_Sales
# 112  24/12/2010   80931415.60
# 107  23/12/2011   76998241.31
# 117  25/11/2011   66593605.26
# 122  26/11/2010   65821003.24
# 79   17/12/2010   61820799.85
# 74   16/12/2011   60085695.94
# 46   10/12/2010   55666770.39
# 41   09/12/2011   55561147.70
# 25   06/04/2012   53502315.87
# 27   06/07/2012   51253021.88
# 5    02/04/2010   50423831.26
# 75   17/02/2012   50197056.96
# 17   04/06/2010   50188543.12
# 42   10/02/2012   50009407.92
# 13   03/12/2010   49909027.88
# 19   05/02/2010   49750740.50
# 34   08/06/2012   49651171.78
# 8    02/12/2011   49390556.49
# 6    02/07/2010   48917484.50
# 10   03/06/2011   48771994.18
# 80   18/02/2011   48716164.12
# 99   22/04/2011   48676692.06
# 18   04/11/2011   48655544.30
# 30   07/05/2010   48503243.52
# 51   11/11/2011   48474224.75
# 67   15/06/2012   48412110.70
# 52   12/02/2010   48336677.63
# 31   07/09/2012   48330059.31
# 1    01/06/2012   48281649.72
# 85   19/02/2010   48276993.78
# ...

# %%
df_top_stores = df.groupby(by=['Store'], as_index=False)['Weekly_Sales'].sum()
df_temperature=df.groupby(by=['Store'], as_index=False)['Temperature'].mean()
df2=df_top_stores.sort_values('Weekly_Sales', ascending=False)
df3=pd.merge(df2,store,on=['Store'],how='right')
df3.head(3)
# Out:
#    Store  Weekly_Sales Type    Size
# 0     20  3.013978e+08    A  203742
# 1      4  2.995440e+08    A  205863
# 2     14  2.889999e+08    A  200898

# %%
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1  05/02/2010      24924.50      False        42.31       2.572
# 1      1     1  12/02/2010      46039.49       True        38.51       2.548
# 2      1     1  19/02/2010      41595.55      False        39.93       2.514
# 3      1     1  26/02/2010      19403.54      False        46.63       2.561
# 4      1     1  05/03/2010      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment Type    Size
# 0         8.106    A  151315
# ...

# %%
model.coef_
# Out:
# array([1036.3035655])

# %%
model.intercept_
# Out:
# 14698473.07031539

# %%
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# 5         1  12/03/2010        57.79       2.667        NaN        NaN
# 6         1  19/03/2010        54.58       2.720        NaN        NaN
# 7         1  26/03/2010        51.45       2.732        NaN        NaN
# 8         1  02/04/2010        62.27       2.719        NaN        NaN
# 9         1  09/04/2010        65.86       2.770        NaN        NaN
# 10        1  16/04/2010        66.32       2.808        NaN        NaN
# 11        1  23/04/2010        64.84       2.795        NaN        NaN
# ...

# %%
df[df.Store==1]
# Out:
#      Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0        1  05/02/2010        42.31       2.572        NaN        NaN
# 1        1  12/02/2010        38.51       2.548        NaN        NaN
# 2        1  19/02/2010        39.93       2.514        NaN        NaN
# 3        1  26/02/2010        46.63       2.561        NaN        NaN
# 4        1  05/03/2010        46.50       2.625        NaN        NaN
# 5        1  12/03/2010        57.79       2.667        NaN        NaN
# 6        1  19/03/2010        54.58       2.720        NaN        NaN
# 7        1  26/03/2010        51.45       2.732        NaN        NaN
# 8        1  02/04/2010        62.27       2.719        NaN        NaN
# 9        1  09/04/2010        65.86       2.770        NaN        NaN
# 10       1  16/04/2010        66.32       2.808        NaN        NaN
# 11       1  23/04/2010        64.84       2.795        NaN        NaN
# ...
