# %%
import pandas as pd
file = "/Users/ladanshamaei/Desktop/ladan/CS/Data Incubator/student/student-mat.csv"
x = pd.read_csv(file,delimiter=";")
x[((x.Medu>3)|(x.Fedu>3))&(x.G3>15)]
import matplotlib.pyplot as plt
plt.bar(x.Medu,x.G3)
plt.xlabel("Mother's Education")
plt.ylabel("Math Grade - out of 20")
plt.title("Math Grade vs. Student's Mother Education")
plt.show()

# %%
plt.bar(x.Fedu,x.G3)
plt.xlabel("Father's Education")
plt.ylabel("Math Grade - out of 20")
plt.title("Math Grade vs. Student's Father Education")
plt.show()
